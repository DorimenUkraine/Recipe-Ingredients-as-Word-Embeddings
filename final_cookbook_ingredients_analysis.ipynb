# %%
from __future__ import print_function
import pandas as pd
# for plotting
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
import numpy as np
pd.pandas.set_option('display.max_columns', None)
#pip install --upgrade gensim
import json
import operator
import collections
import re
import numpy as np
import pandas as pd
import nltk
from gensim.models import word2vec
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import seaborn as sns
# %matplotlib inline

# %%
train_dataset = json.load(open('train.json','r'))
test_dataset = json.load(open('test.json','r'))

# %%
ingredients = list()

for recipe in train_dataset:
    for ingredient in recipe[u'ingredients']:
        ingredients.append(ingredient.strip())

cuisines = list()
for recipe in train_dataset:
    cuisines.append(recipe[u'cuisine'].strip())
print("Total recipes in the train corpus",len(cuisines))
# Out:
# Total recipes in the train corpus 39774

# %% [markdown]
# # Dictionary of output labels

# %%
labels = set(cuisines)
labels = list(labels)
labels = { labels[i] : i for i in range(0, len(labels) ) }
print(labels)
# Out:
# {'french': 0, 'mexican': 1, 'korean': 2, 'spanish': 3, 'chinese': 4, 'indian': 5, 'cajun_creole': 6, 'filipino': 7, 'brazilian': 8, 'italian': 9, 'irish': 10, 'moroccan': 11, 'southern_us': 12, 'japanese': 13, 'russian': 14, 'jamaican': 15, 'greek': 16, 'thai': 17, 'british': 18, 'vietnamese': 19}

# %%
print('ingredients in the dataset: ',len((ingredients)))
print('unique ingredients in the dataset: ',len(set(ingredients)))
# Out:
# ingredients in the dataset:  428275
# unique ingredients in the dataset:  6714

# %% [markdown]
# # Cleaning

# %%
import inflect
stemmer = inflect.engine()

recipes_as_sentences_list = list()

for recipe in train_dataset:
    clean_recipe = list()
    for ingredient in recipe['ingredients']:
        ingredient = re.sub(r'[^a-zA-Z\s]+', '', ingredient)
        ingredient =  re.sub(r'\(.*oz.\)|large|medium|small|extra|low-fat|warm|plain|hot|crushed|crumbles|ground|minced|chopped|sliced|heavy|grated|all-purpose|shredded|breakfast|whole|crumbled|self rising|low sodium|flat|diced|unsweetened','', ingredient)
        if stemmer.singular_noun(ingredient) is not False:
            ingredient = stemmer.singular_noun(ingredient)
        words_in_ingredients = nltk.tag.pos_tag(ingredient.split())
        words_in_ingredients=[word[0] for word in words_in_ingredients if word[1] in ('NN')]
        ingredient = " ".join(words_in_ingredients)
        ingredient = ingredient.strip().lower()
        clean_recipe.append(ingredient)
    while("" in clean_recipe) :
        clean_recipe.remove("")
    recipes_as_sentences_list.append(clean_recipe)

# %%
u_ingredients = set()
for recipe in recipes_as_sentences_list:
    for ingredient in recipe:
        u_ingredients.add(ingredient)
print('unique ingredients after cleaning the dataset: ',len(u_ingredients))
# Out:
# unique ingredients after cleaning the dataset:  3903

# %% [markdown]
# ## TODO: Check why  and what '1719' ingredients were removed during cleaning.

# %%
ingredients_removed_in_cleaning = u_ingredients.difference(set(ingredients))
print(len(ingredients_removed_in_cleaning))
# Out:
# 1719

# %% [markdown]
# # Generating context vectors of ingredients from the pre-trained word2vec model

# %%
num_features = 300              
min_word_count = 1                   
num_workers = 4
context = 10                                                                                

model = word2vec.Word2Vec(recipes_as_sentences_list, workers=num_workers, \
            size=num_features, min_count = min_word_count, \
            window = context)

# %%
print("Before cleaning: ")
print(train_dataset[12342]["ingredients"])
print("After cleaning: ")
print(recipes_as_sentences_list[12342])
print("=======================================================")
print("Before cleaning: ")
print(train_dataset[122]["ingredients"])
print("After cleaning: ")
print(recipes_as_sentences_list[122])
# Out:
# Before cleaning:
# ['light soy sauce', 'peeled shrimp', 'brown sugar', 'green onions', 'chicken stock', 'fresh ginger root', 'boneless pork loin', 'chinese rice wine', 'wonton wrappers']
# After cleaning:
# ['soy sauce', 'shrimp', 'brown sugar', 'onion', 'chicken stock', 'ginger root', 'boneless pork loin', 'rice wine', 'wonton wrapper']
# =======================================================
# Before cleaning:
# ['tomato sauce', 'ground black pepper', 'garlic', 'scallions', 'chipotles in adobo', 'avocado', 'dried thyme', 'instant white rice', 'cilantro leaves', 'coconut milk', 'water', 'red beans', 'chopped celery', 'skinless chicken thighs', 'onions', 'lime zest', 'lime juice', 'lime wedges', 'salt', 'carrots']
# After cleaning:
# ['tomato sauce', 'pepper', 'garlic', 'scallion', 'chipotle adobo', 'avocado', 'thyme', 'rice', 'cilantro leaf', 'coconut milk', 'water', 'bean', 'celery', 'skinless chicken thigh', 'onion', 'lime zest', 'lime juice', 'lime wedge', 'salt', 'carrot']

# %%
model.similarity('ginger root', 'ginger')
# Out:
# 0.9493743

# %%
print(model.wv.vectors.shape)
vocab = model.wv.vocab
#print(model['olive'])
# Out:
# (3903, 300)

# %%
ingredients_new = list()
for recipe in recipes_as_sentences_list:
    for ingredient in recipe:
        ingredients_new.append(ingredient.strip())
print(len((ingredients_new)))
ingredients_new_set = set(ingredients_new)
print(len((ingredients_new_set)))

#so there are no unknown
# Out:
# 416965
# 3903

# %%
unknown_ingredients = []
for ingredient in ingredients_new_set:
    if ingredient not in vocab.keys():
        unknown_ingredients.append(ingredient)

# %%
print(len(unknown_ingredients))
# Out:
# 0

# %%
def sent_vectorizer(sent, model):
    sent_vec =[]
    numw = 0
    sent = [x for x in sent if x not in unknown_ingredients]
    for w in sent:
        try:
            if numw == 0:
                sent_vec = model[w]
            else:
                sent_vec = np.add(sent_vec, model[w])
            numw+=1
        except:
            pass
    return np.asarray(sent_vec) / numw

# %%
recipes_as_context_vectors_of_ingredients=[]
for sentence in recipes_as_sentences_list:
    recipes_as_context_vectors_of_ingredients.append(sent_vectorizer(sentence, model))

# %%
print("Length of vector", len(recipes_as_context_vectors_of_ingredients[0]))
print(recipes_as_sentences_list[0])
print("Context Vectors taindataset count records: ", len(recipes_as_context_vectors_of_ingredients))
print("Original taindataset count records: ",len(recipes_as_sentences_list))
# Out:
# Length of vector 300
# ['romaine lettuce', 'olive', 'grape tomato', 'garlic', 'pepper', 'onion', 'feta cheese']
# Context Vectors taindataset count records:  39774
# Original taindataset count records:  39774

# %% [markdown]
# # Update json tarindataset

# %%
for i,recipe in enumerate(train_dataset):
    recipe[u'ingredients'] = recipes_as_context_vectors_of_ingredients[i]
    recipe[u'cuisine'] = labels[recipe[u'cuisine']]

# %% [markdown]
# # Convert Json to Pandas dataframe: Only for understanding and taken output variable from this dataframe

# %%
from pandas.io.json import json_normalize
train_dataset_new = json_normalize(train_dataset)
train_dataset_new.drop(['id'],axis=1,inplace=True)
train_dataset_new.head()
# Out:
#    cuisine                                        ingredients
# 0       16  [0.045165855, -0.18682246, -0.040208463, -0.14...
# 1       12  [-0.13681337, -0.068644695, -0.18498793, 0.160...
# 2        7  [-0.037796352, 0.18375583, -0.06670243, 0.0791...
# 3        5  [0.17552686, -0.026997099, -0.21593082, 0.2682...
# 4        5  [-0.043211795, -0.09228353, -0.20805445, 0.235...

# %% [markdown]
# # Machine Learning

# %%
data = pd.DataFrame(recipes_as_context_vectors_of_ingredients)
print(data.shape)
data.head()
# Out:
# (39774, 300)
#         0         1         2         3         4         5         6    \
# 0  0.045166 -0.186822 -0.040208 -0.148948  0.220548 -0.046828 -0.242472
# 1 -0.136813 -0.068645 -0.184988  0.160385  0.605337  0.204769  0.180372
# 2 -0.037796  0.183756 -0.066702  0.079153  0.578104  0.209741  0.093224
# 3  0.175527 -0.026997 -0.215931  0.268228  0.289357 -0.033960  0.111615
# 4 -0.043212 -0.092284 -0.208054  0.235734  0.575732  0.515774  0.016623
#
#         7         8         9         10        11        12        13   \
# 0  0.109549  0.050461 -0.167338 -0.032712  0.033797  0.255913  0.217057
# 1  0.049821 -0.185474 -0.040328  0.249707 -0.027790 -0.193371 -0.089368
# 2 -0.012469 -0.230706 -0.206549  0.177060 -0.174076 -0.256894 -0.011105
# 3  0.100245 -0.092040  0.055896  0.019615 -0.105521 -0.111446 -0.093769
# 4  0.170625 -0.132499 -0.171158  0.007030 -0.163291 -0.042852 -0.147468
#
#         14        15        16        17        18        19        20   \
# 0  0.183838  0.186438  0.212896 -0.100058 -0.030988 -0.006509 -0.068120
# 1  0.090707 -0.329384  0.013527 -0.136256  0.308313 -0.150665  0.117663
# 2 -0.020571 -0.029270  0.030089 -0.202894  0.188136 -0.037913 -0.112961
# 3  0.150726 -0.246128 -0.047201 -0.020664  0.229966 -0.196029 -0.010625
# 4  0.219074 -0.203628  0.053504 -0.168854  0.484223 -0.211108 -0.146307
#
#         21        22        23        24        25        26        27   \
# 0 -0.134243  0.187796 -0.322893  0.011005  0.460759 -0.013859 -0.057261
# 1 -0.055222  0.071557 -0.131721  0.021932  0.340078 -0.157066 -0.059208
# 2 -0.189059  0.044375 -0.145863  0.021810  0.061613 -0.242331 -0.038762
# 3 -0.198361 -0.216467 -0.177472 -0.194045  0.056400 -0.148496  0.096536
# 4 -0.194365  0.075488 -0.324019  0.043260  0.196377 -0.234084 -0.049732
#
#         28        29        30        31        32        33        34   \
# 0  0.127298  0.007886  0.258933 -0.506016  0.296045  0.161354  0.099015
# 1 -0.053352  0.116670  0.110041  0.040399  0.128498 -0.124636  0.395918
# 2 -0.058656  0.064862 -0.089704  0.022420  0.051291  0.039973  0.171947
# 3 -0.101129  0.076192  0.082319  0.139951 -0.058008  0.011855 -0.008562
# 4 -0.211761 -0.048073  0.099765  0.149427  0.034685  0.083637  0.007568
#
#         35        36        37        38        39        40        41   \
# 0  0.242064 -0.085300  0.366964 -0.127331  0.042244  0.008465  0.211612
# 1  0.217364 -0.000901  0.034272 -0.280087  0.094047  0.212103  0.210389
# 2  0.111342 -0.000376  0.045203 -0.092069  0.173853  0.050093 -0.089826
# 3  0.205246 -0.006028  0.105041 -0.123183  0.205610  0.213346  0.134285
# 4  0.326553 -0.092959 -0.153894 -0.161261  0.238498  0.246148  0.021819
#
#         42        43        44        45        46        47        48   \
# 0 -0.109408 -0.189282  0.298782 -0.043736  0.306647  0.022697  0.153046
# 1 -0.179771 -0.220253 -0.095805  0.191203  0.093283 -0.181053 -0.151323
# 2  0.054013 -0.180701 -0.185815  0.047166  0.074568  0.038425  0.017585
# 3  0.021787 -0.004310 -0.185494  0.014104 -0.085029  0.042273 -0.061752
# 4 -0.014147 -0.094546 -0.153265 -0.003046  0.002818 -0.035223 -0.108424
#
#         49        50        51        52        53        54        55   \
# 0  0.174936 -0.159109 -0.143167 -0.086205 -0.189728  0.254133 -0.207078
# 1  0.207284 -0.119463 -0.161943  0.030371 -0.183043  0.086317 -0.058436
# 2  0.069974  0.071706 -0.095597 -0.074911 -0.183031  0.123511 -0.186524
# 3  0.045825 -0.040905 -0.075722 -0.158647 -0.140146  0.164424 -0.141636
# 4  0.221711 -0.083854 -0.116045 -0.038901 -0.284809  0.259322 -0.047321
#
#         56        57        58        59        60        61        62   \
# 0  0.255723  0.107128  0.149582 -0.286775  0.421800  0.169201  0.080213
# 1  0.197331 -0.082239  0.420904 -0.198066  0.332795  0.025504 -0.135660
# 2 -0.045801 -0.188901  0.200282 -0.118050  0.360095  0.033992 -0.168182
# 3  0.143469 -0.069993  0.269288 -0.258826  0.198591  0.073083 -0.138835
# 4  0.104747 -0.122619  0.207808 -0.349174  0.443099 -0.036347 -0.053357
#
#         63        64        65        66        67        68        69   \
# 0 -0.087006  0.367575  0.278083  0.018064 -0.100739 -0.029645  0.101898
# 1  0.064031  0.211713  0.364132  0.273247  0.147763 -0.072000  0.281877
# 2  0.069825  0.267035  0.367270  0.187518  0.195883  0.045903  0.050817
# 3  0.145450  0.117417  0.108120  0.121566 -0.104214 -0.051169  0.115911
# 4 -0.015951  0.162314  0.275834  0.307001  0.068073 -0.139125  0.132277
#
#         70        71        72        73        74        75        76   \
# 0  0.334677  0.084815  0.085055  0.130905 -0.037206 -0.057518 -0.201832
# 1  0.111967  0.223240  0.028282  0.128638 -0.001253 -0.104079 -0.197752
# 2  0.062953  0.089514  0.087824  0.081112 -0.115882 -0.186354 -0.125509
# 3  0.196901  0.039159 -0.044014  0.121168 -0.045754 -0.104490 -0.153972
# 4  0.069833 -0.136643  0.136538  0.285088 -0.010576 -0.145058 -0.226428
#
#         77        78        79        80        81        82        83   \
# 0  0.383903  0.052853 -0.290861 -0.311752  0.147616 -0.069472  0.034865
# 1  0.122620  0.043570  0.268345 -0.045128  0.049385  0.035330  0.161885
# 2  0.239905  0.150612  0.062335 -0.114164  0.206834 -0.174423 -0.143383
# 3  0.084995 -0.022497 -0.064864 -0.030642 -0.021505  0.120058 -0.033323
# 4  0.052905  0.355642 -0.147669 -0.110771  0.139467 -0.111484 -0.086481
#
#         84        85        86        87        88        89        90   \
# 0  0.039413  0.057296 -0.032883  0.178930 -0.041066 -0.291091 -0.282419
# 1 -0.338942  0.371122 -0.052994  0.244417 -0.287926 -0.218817 -0.021330
# 2 -0.194942  0.389972  0.106455  0.259786 -0.299455 -0.290938  0.021807
# 3 -0.222691  0.242486  0.092962  0.018603 -0.219664 -0.154725 -0.002171
# 4 -0.349371  0.295586 -0.089981 -0.067171 -0.360450 -0.333718 -0.238447
#
#         91        92        93        94        95        96        97   \
# 0  0.603306 -0.442489 -0.327670 -0.263256  0.461867  0.023616  0.439441
# 1  0.395019 -0.372362 -0.277778  0.037163  0.295471  0.157661  0.314650
# 2  0.434425 -0.223086 -0.174660 -0.072449  0.191839  0.075741  0.240822
# 3  0.289039 -0.125069 -0.281204  0.010688  0.262193  0.027944  0.151230
# 4  0.463355 -0.252728 -0.339298  0.028461  0.257459  0.152926  0.201800
#
#         98        99        100       101       102       103       104  \
# 0  0.235254  0.373382 -0.190634 -0.221493 -0.667009 -0.082607 -0.006312
# 1  0.176541  0.213506 -0.021481  0.029486 -0.498019 -0.047550 -0.255754
# 2  0.281865  0.108383 -0.161810 -0.187901 -0.342081  0.009544 -0.260808
# 3  0.125055  0.188927 -0.053681 -0.025389 -0.292639  0.049411 -0.285139
# 4  0.342497  0.219784 -0.138514  0.059858 -0.317369  0.072370 -0.139294
#
#         105       106       107       108       109       110       111  \
# 0 -0.390579 -0.134744  0.199869 -0.047040 -0.095199  0.438204  0.175492
# 1 -0.117963  0.088568  0.134302 -0.402002 -0.265234  0.383252  0.159932
# 2 -0.288075  0.051073  0.004536 -0.318183 -0.414206  0.147566  0.024906
# 3 -0.121680  0.051281  0.179292 -0.236445 -0.378220  0.299338 -0.154108
# 4 -0.022898 -0.017022  0.143663 -0.196159 -0.430140  0.063951 -0.006114
#
#         112       113       114       115       116       117       118  \
# 0 -0.114987 -0.110947 -0.409854 -0.133315 -0.233369  0.179327  0.113631
# 1 -0.530212 -0.060001 -0.163197 -0.357970 -0.237835  0.295675 -0.194183
# 2 -0.310370  0.054972 -0.066917 -0.145379 -0.212008  0.321734 -0.123401
# 3 -0.245200 -0.010455 -0.225823 -0.358113 -0.182551  0.267396 -0.149492
# 4 -0.278787 -0.081952 -0.072987 -0.280205 -0.174310  0.139281  0.078958
#
#         119       120       121       122       123       124       125  \
# 0  0.124691 -0.231633  0.082733 -0.298423  0.326031  0.329030  0.157246
# 1 -0.003883 -0.318181 -0.061075  0.115886  0.112178  0.226662  0.222194
# 2 -0.110092 -0.147035 -0.252981  0.200497 -0.093486  0.040278  0.114311
# 3 -0.035876 -0.161939 -0.047609  0.142945  0.033835  0.010732  0.112518
# 4 -0.020992 -0.156900 -0.032071  0.064326  0.070919  0.260380 -0.009741
#
#         126       127       128       129       130       131       132  \
# 0  0.043023 -0.406806 -0.019210  0.097610  0.154527 -0.028668  0.007515
# 1  0.292609 -0.187217  0.144786  0.055155  0.258740  0.020244 -0.014791
# 2  0.311769 -0.078079  0.197749 -0.043474  0.004409  0.040359  0.140259
# 3  0.162255 -0.213752  0.064943 -0.017400  0.081982  0.071264  0.155906
# 4  0.341686 -0.253904  0.113620  0.167235  0.139025  0.124136 -0.093230
#
#         133       134       135       136       137       138       139  \
# 0  0.157075  0.274354 -0.145701  0.505673 -0.304795 -0.314147  0.487233
# 1  0.063200  0.116612 -0.150365  0.035586 -0.136915 -0.114242 -0.113486
# 2  0.057140  0.066875 -0.129667  0.089897  0.024200  0.014155  0.004968
# 3 -0.046345  0.156536 -0.199489  0.133528  0.012668 -0.205632 -0.123320
# 4  0.060153  0.120347 -0.082689 -0.085486 -0.014939  0.048910  0.088500
#
#         140       141       142       143       144       145       146  \
# 0  0.017175 -0.057374 -0.086568 -0.270234 -0.086852  0.188279 -0.033689
# 1  0.002597  0.221838  0.006201 -0.417312  0.114375 -0.070995  0.023327
# 2  0.154011  0.245434 -0.032879 -0.231631 -0.006785 -0.062929  0.119299
# 3 -0.006324  0.304931 -0.218730 -0.070735 -0.077876  0.132799  0.049408
# 4 -0.039743  0.280168 -0.237062 -0.187121  0.053668  0.308144  0.081186
#
#         147       148       149       150       151       152       153  \
# 0 -0.337834  0.145169  0.113222 -0.062634 -0.435245 -0.306094  0.171984
# 1 -0.106340  0.107593  0.105678  0.049740 -0.264606 -0.140144 -0.431648
# 2  0.005194  0.018536 -0.070187  0.182811 -0.284503 -0.137163 -0.269879
# 3  0.060700 -0.032213 -0.001472  0.045498 -0.155506 -0.214697 -0.076349
# 4 -0.239390  0.106350  0.045241  0.160671 -0.389159 -0.318960 -0.100055
#
#         154       155       156       157       158       159       160  \
# 0 -0.089011 -0.144320  0.123949  0.113529 -0.320610 -0.164778 -0.135140
# 1 -0.477079 -0.146103 -0.017253 -0.094708 -0.006980  0.097614 -0.086166
# 2 -0.315196  0.115568  0.005625 -0.286776  0.050975  0.183587  0.027923
# 3 -0.341843  0.058911  0.068045 -0.076639  0.127489  0.175458  0.017116
# 4 -0.271291  0.019279 -0.013083  0.012124  0.110755  0.188432 -0.248873
#
#         161       162       163       164       165       166       167  \
# 0 -0.064684 -0.177959  0.108942 -0.544299  0.027349  0.356871 -0.118159
# 1  0.129233 -0.147552  0.076569 -0.254678  0.192301  0.274385  0.036670
# 2  0.033633 -0.129598  0.120354 -0.219440  0.065142  0.297414  0.051387
# 3 -0.132579 -0.207581  0.020774 -0.165189  0.009823  0.341552 -0.030435
# 4  0.013961 -0.077937  0.017908 -0.267983  0.054784  0.194690  0.147475
#
#         168       169       170       171       172       173       174  \
# 0  0.238216  0.115817  0.297036  0.648095 -0.648513 -0.161086  0.081983
# 1 -0.010373 -0.011478  0.194060  0.283602 -0.184210 -0.179025  0.102773
# 2  0.087660  0.113616  0.156505  0.268380 -0.213109 -0.162401  0.244111
# 3  0.186506  0.275057  0.176023  0.270148 -0.420341 -0.105872  0.000934
# 4  0.233133  0.101489  0.083907  0.225489 -0.407844 -0.133008  0.103064
#
#         175       176       177       178       179       180       181  \
# 0  0.004553 -0.661199 -0.273057 -0.232438  0.492083 -0.091234  0.121208
# 1 -0.073802 -0.166479 -0.130287 -0.178733 -0.090959 -0.019706  0.122582
# 2  0.173746 -0.095381  0.039599 -0.409037  0.061887  0.001013  0.394118
# 3  0.210533 -0.285709 -0.166449 -0.438567 -0.156536 -0.192139  0.416030
# 4  0.113539 -0.245718  0.075684 -0.432696 -0.023290 -0.079878  0.450487
#
#         182       183       184       185       186       187       188  \
# 0  0.234660 -0.040876  0.214551  0.206691 -0.378760  0.091240 -0.276305
# 1 -0.048456  0.074011 -0.101331 -0.030236 -0.166486  0.220083 -0.124024
# 2 -0.006244  0.158514  0.081809  0.018846 -0.086353  0.219369 -0.096790
# 3  0.020057  0.055813 -0.165853  0.126191 -0.099354  0.152571 -0.237819
# 4  0.103111  0.028772  0.104631  0.237303 -0.150501  0.032863 -0.183735
#
#         189       190       191       192       193       194       195  \
# 0  0.348394  0.189202 -0.039899  0.007252  0.023891  0.180608 -0.044694
# 1  0.005842  0.101624 -0.201897 -0.151110 -0.031324  0.047048 -0.312679
# 2 -0.021151  0.161172 -0.251882 -0.258181 -0.009543  0.119414 -0.053714
# 3 -0.087801 -0.033170 -0.143659 -0.210206 -0.007968  0.199198 -0.239404
# 4  0.123943  0.331276 -0.100025 -0.178404  0.200769  0.075553 -0.236437
#
#         196       197       198       199       200       201       202  \
# 0 -0.113823  0.068996 -0.500981  0.261934  0.043847 -0.401673 -0.230929
# 1 -0.076372  0.061432 -0.332923 -0.037514  0.292480 -0.307352  0.126516
# 2  0.043053  0.217421 -0.133478  0.008698  0.249996 -0.257376  0.069191
# 3 -0.041680  0.172614 -0.128231  0.002829  0.426928 -0.504743  0.088622
# 4 -0.059251  0.161967 -0.029123  0.083928  0.237252 -0.381130  0.059811
#
#         203       204       205       206       207       208       209  \
# 0  0.057447  0.205273 -0.200156 -0.412095  0.099247 -0.012548 -0.704206
# 1  0.038016  0.128947 -0.103601 -0.156899 -0.302557 -0.314021 -0.465241
# 2 -0.082731  0.008223 -0.268027 -0.249785 -0.275209 -0.186274 -0.265973
# 3 -0.060581  0.138801 -0.233322 -0.074589 -0.303754 -0.418314 -0.406320
# 4 -0.003736  0.093896 -0.008865 -0.099916 -0.076496 -0.162444 -0.405952
#
#         210       211       212       213       214       215       216  \
# 0 -0.237615 -0.304809  0.399941 -0.150039  0.057990 -0.394538  0.487589
# 1 -0.111973 -0.293453  0.252497 -0.001780 -0.089908 -0.155549  0.246367
# 2  0.007530  0.008643  0.043888 -0.111982 -0.025384 -0.011983  0.333552
# 3 -0.157227 -0.214343  0.198613 -0.410722 -0.057646 -0.009641  0.147896
# 4 -0.313231 -0.083848  0.270146 -0.215093 -0.277706 -0.112221  0.199396
#
#         217       218       219       220       221       222       223  \
# 0  0.292059 -0.145009 -0.312687  0.369353 -0.254717 -0.082460 -0.041843
# 1  0.341913 -0.101823 -0.235577  0.219583 -0.044168  0.082604  0.137532
# 2  0.387888 -0.101080 -0.152826  0.031806 -0.091864  0.017828  0.063288
# 3  0.308647  0.117655 -0.209586  0.095574  0.039819 -0.065898  0.207267
# 4  0.292364  0.010380 -0.046929  0.153994 -0.264840  0.174333  0.211124
#
#         224       225       226       227       228       229       230  \
# 0 -0.054188  0.541652 -0.327549 -0.123172  0.026107  0.611200  0.024999
# 1 -0.009375  0.323461 -0.325211 -0.112569  0.035180  0.322089  0.292749
# 2 -0.018386  0.348509 -0.153647 -0.053546  0.001174  0.225896  0.014327
# 3 -0.040239  0.277608 -0.202747 -0.078581  0.195786 -0.044764 -0.145326
# 4  0.101847  0.423652 -0.365786 -0.220063  0.069041  0.415262 -0.009577
#
#         231       232       233       234       235       236       237  \
# 0  0.263751 -0.162226  0.190246  0.009556 -0.056675 -0.358250  0.259278
# 1 -0.065652  0.015746  0.228130 -0.047630 -0.074180 -0.288872  0.313230
# 2  0.016892  0.010219 -0.045066 -0.030950 -0.038106 -0.261223  0.184943
# 3 -0.145257 -0.120600  0.162439 -0.028335  0.190103 -0.057958  0.038917
# 4 -0.073692 -0.015202  0.003313  0.101365  0.169221 -0.225544  0.289056
#
#         238       239       240       241       242       243       244  \
# 0 -0.118742  0.078036 -0.371248  0.163460  0.123380  0.073944  0.094856
# 1 -0.127965  0.046234 -0.180781 -0.044940  0.050943 -0.077384 -0.269473
# 2 -0.091477  0.092370 -0.154164 -0.062558  0.046808  0.019012 -0.108283
# 3  0.059067  0.066020  0.129214 -0.053936  0.013898 -0.071552 -0.206399
# 4  0.007851  0.013793 -0.382699  0.089743  0.008678  0.020631 -0.115775
#
#         245       246       247       248       249       250       251  \
# 0 -0.374406  0.075558 -0.270153 -0.604539  0.019539 -0.008587  0.439927
# 1  0.072831  0.116604 -0.168891 -0.229783  0.247559  0.037334  0.237188
# 2 -0.068228  0.056464 -0.098448 -0.285469  0.248407 -0.035714  0.107565
# 3  0.289473  0.175494  0.122831 -0.199611  0.349668 -0.086311  0.207421
# 4  0.218365 -0.062471  0.002519 -0.286133  0.389812 -0.052098  0.272734
#
#         252       253       254       255       256       257       258  \
# 0  0.039825  0.188154 -0.379745  0.210087 -0.085910  0.056213 -0.022947
# 1  0.058849 -0.157616 -0.256954  0.109634 -0.112640  0.110275  0.205120
# 2 -0.081946 -0.190026 -0.149920 -0.113285 -0.126224  0.121430 -0.019094
# 3 -0.173384 -0.145102 -0.136669  0.103072 -0.094101 -0.190838  0.053738
# 4 -0.284207 -0.078399 -0.276351  0.199086  0.048582  0.085285 -0.061025
#
#         259       260       261       262       263       264       265  \
# 0  0.209829 -0.346199  0.232295 -0.160025 -0.139382  0.597834  0.286008
# 1 -0.016592  0.086210  0.242008  0.145985 -0.115243  0.204453  0.027921
# 2 -0.020133  0.148577  0.103648  0.073967 -0.001371  0.085125  0.115746
# 3  0.161352 -0.066255 -0.018375  0.268434 -0.046975  0.015129  0.041884
# 4  0.038787  0.053211  0.252661 -0.013734 -0.180501  0.293762  0.028562
#
#         266       267       268       269       270       271       272  \
# 0  0.060557 -0.062150  0.075570 -0.494240 -0.026763  0.198833  0.116072
# 1  0.105096  0.192051  0.116738 -0.107490  0.024690 -0.069206  0.154065
# 2  0.190196  0.111641  0.008371 -0.230572 -0.027785 -0.234586 -0.014762
# 3  0.046330  0.213024  0.066065  0.089257  0.095816  0.009813 -0.021770
# 4 -0.011436  0.117337 -0.051972 -0.110146  0.047820 -0.138809  0.121214
#
#         273       274       275       276       277       278       279  \
# 0  0.043847 -0.073603 -0.102847 -0.263390  0.052392 -0.461331  0.035556
# 1  0.275091 -0.017957  0.179729 -0.172441 -0.011095 -0.171192  0.046851
# 2  0.005762 -0.030596  0.326494 -0.039787 -0.078762 -0.070605  0.121084
# 3 -0.091973  0.080057  0.030445  0.033235  0.031468 -0.012104 -0.195555
# 4  0.124878 -0.000890  0.294493  0.008790 -0.037704 -0.179488 -0.052334
#
#         280       281       282       283       284       285       286  \
# 0  0.104598 -0.242080  0.499110 -0.069143 -0.250825 -0.146353 -0.033547
# 1 -0.251241  0.012877  0.159934 -0.160145 -0.038436  0.079178  0.089671
# 2 -0.195990  0.177814  0.157342 -0.125553  0.033584  0.002932  0.130796
# 3 -0.220033  0.048767  0.277926 -0.120957 -0.016782 -0.086586  0.030298
# 4 -0.114976  0.044646  0.198367 -0.120091  0.099874  0.042875  0.095566
#
#         287       288       289       290       291       292       293  \
# 0  0.205885  0.253693 -0.447286 -0.378392  0.163971  0.358968 -0.275628
# 1  0.289350  0.191247 -0.265801 -0.169838  0.152730  0.239008 -0.206390
# 2  0.019763 -0.004392 -0.071327 -0.099395  0.064350  0.266951 -0.348339
# 3  0.111823  0.010949  0.187981 -0.035402  0.021776 -0.012220 -0.189378
# 4  0.139868 -0.035607 -0.139156 -0.287867 -0.016443  0.181116 -0.339001
#
#         294       295       296       297       298       299
# 0 -0.135233 -0.086473 -0.145747  0.550188  0.094567 -0.226367
# 1 -0.017012 -0.072159 -0.322869  0.037754 -0.082875 -0.116248
# 2  0.049832 -0.107754 -0.292320  0.152704  0.037779 -0.076041
# 3 -0.012176 -0.143797 -0.213756  0.115597  0.035713  0.056161
# 4  0.199393 -0.273069 -0.280253  0.282349  0.203717 -0.095882

# %%
label_data = train_dataset_new.cuisine
print(label_data.shape)
label_data.head()
final_data = pd.concat([data, label_data], axis=1)
print(final_data.shape)
final_data.head()
# Out:
# (39774,)
# (39774, 301)
#           0         1         2         3         4         5         6  \
# 0  0.045166 -0.186822 -0.040208 -0.148948  0.220548 -0.046828 -0.242472
# 1 -0.136813 -0.068645 -0.184988  0.160385  0.605337  0.204769  0.180372
# 2 -0.037796  0.183756 -0.066702  0.079153  0.578104  0.209741  0.093224
# 3  0.175527 -0.026997 -0.215931  0.268228  0.289357 -0.033960  0.111615
# 4 -0.043212 -0.092284 -0.208054  0.235734  0.575732  0.515774  0.016623
#
#           7         8         9        10        11        12        13  \
# 0  0.109549  0.050461 -0.167338 -0.032712  0.033797  0.255913  0.217057
# 1  0.049821 -0.185474 -0.040328  0.249707 -0.027790 -0.193371 -0.089368
# 2 -0.012469 -0.230706 -0.206549  0.177060 -0.174076 -0.256894 -0.011105
# 3  0.100245 -0.092040  0.055896  0.019615 -0.105521 -0.111446 -0.093769
# 4  0.170625 -0.132499 -0.171158  0.007030 -0.163291 -0.042852 -0.147468
#
#          14        15        16        17        18        19        20  \
# 0  0.183838  0.186438  0.212896 -0.100058 -0.030988 -0.006509 -0.068120
# 1  0.090707 -0.329384  0.013527 -0.136256  0.308313 -0.150665  0.117663
# 2 -0.020571 -0.029270  0.030089 -0.202894  0.188136 -0.037913 -0.112961
# 3  0.150726 -0.246128 -0.047201 -0.020664  0.229966 -0.196029 -0.010625
# 4  0.219074 -0.203628  0.053504 -0.168854  0.484223 -0.211108 -0.146307
#
#          21        22        23        24        25        26        27  \
# 0 -0.134243  0.187796 -0.322893  0.011005  0.460759 -0.013859 -0.057261
# 1 -0.055222  0.071557 -0.131721  0.021932  0.340078 -0.157066 -0.059208
# 2 -0.189059  0.044375 -0.145863  0.021810  0.061613 -0.242331 -0.038762
# 3 -0.198361 -0.216467 -0.177472 -0.194045  0.056400 -0.148496  0.096536
# 4 -0.194365  0.075488 -0.324019  0.043260  0.196377 -0.234084 -0.049732
#
#          28        29        30        31        32        33        34  \
# 0  0.127298  0.007886  0.258933 -0.506016  0.296045  0.161354  0.099015
# 1 -0.053352  0.116670  0.110041  0.040399  0.128498 -0.124636  0.395918
# 2 -0.058656  0.064862 -0.089704  0.022420  0.051291  0.039973  0.171947
# 3 -0.101129  0.076192  0.082319  0.139951 -0.058008  0.011855 -0.008562
# 4 -0.211761 -0.048073  0.099765  0.149427  0.034685  0.083637  0.007568
#
#          35        36        37        38        39        40        41  \
# 0  0.242064 -0.085300  0.366964 -0.127331  0.042244  0.008465  0.211612
# 1  0.217364 -0.000901  0.034272 -0.280087  0.094047  0.212103  0.210389
# 2  0.111342 -0.000376  0.045203 -0.092069  0.173853  0.050093 -0.089826
# 3  0.205246 -0.006028  0.105041 -0.123183  0.205610  0.213346  0.134285
# 4  0.326553 -0.092959 -0.153894 -0.161261  0.238498  0.246148  0.021819
#
#          42        43        44        45        46        47        48  \
# 0 -0.109408 -0.189282  0.298782 -0.043736  0.306647  0.022697  0.153046
# 1 -0.179771 -0.220253 -0.095805  0.191203  0.093283 -0.181053 -0.151323
# 2  0.054013 -0.180701 -0.185815  0.047166  0.074568  0.038425  0.017585
# 3  0.021787 -0.004310 -0.185494  0.014104 -0.085029  0.042273 -0.061752
# 4 -0.014147 -0.094546 -0.153265 -0.003046  0.002818 -0.035223 -0.108424
#
#          49        50        51        52        53        54        55  \
# 0  0.174936 -0.159109 -0.143167 -0.086205 -0.189728  0.254133 -0.207078
# 1  0.207284 -0.119463 -0.161943  0.030371 -0.183043  0.086317 -0.058436
# 2  0.069974  0.071706 -0.095597 -0.074911 -0.183031  0.123511 -0.186524
# 3  0.045825 -0.040905 -0.075722 -0.158647 -0.140146  0.164424 -0.141636
# 4  0.221711 -0.083854 -0.116045 -0.038901 -0.284809  0.259322 -0.047321
#
#          56        57        58        59        60        61        62  \
# 0  0.255723  0.107128  0.149582 -0.286775  0.421800  0.169201  0.080213
# 1  0.197331 -0.082239  0.420904 -0.198066  0.332795  0.025504 -0.135660
# 2 -0.045801 -0.188901  0.200282 -0.118050  0.360095  0.033992 -0.168182
# 3  0.143469 -0.069993  0.269288 -0.258826  0.198591  0.073083 -0.138835
# 4  0.104747 -0.122619  0.207808 -0.349174  0.443099 -0.036347 -0.053357
#
#          63        64        65        66        67        68        69  \
# 0 -0.087006  0.367575  0.278083  0.018064 -0.100739 -0.029645  0.101898
# 1  0.064031  0.211713  0.364132  0.273247  0.147763 -0.072000  0.281877
# 2  0.069825  0.267035  0.367270  0.187518  0.195883  0.045903  0.050817
# 3  0.145450  0.117417  0.108120  0.121566 -0.104214 -0.051169  0.115911
# 4 -0.015951  0.162314  0.275834  0.307001  0.068073 -0.139125  0.132277
#
#          70        71        72        73        74        75        76  \
# 0  0.334677  0.084815  0.085055  0.130905 -0.037206 -0.057518 -0.201832
# 1  0.111967  0.223240  0.028282  0.128638 -0.001253 -0.104079 -0.197752
# 2  0.062953  0.089514  0.087824  0.081112 -0.115882 -0.186354 -0.125509
# 3  0.196901  0.039159 -0.044014  0.121168 -0.045754 -0.104490 -0.153972
# 4  0.069833 -0.136643  0.136538  0.285088 -0.010576 -0.145058 -0.226428
#
#          77        78        79        80        81        82        83  \
# 0  0.383903  0.052853 -0.290861 -0.311752  0.147616 -0.069472  0.034865
# 1  0.122620  0.043570  0.268345 -0.045128  0.049385  0.035330  0.161885
# 2  0.239905  0.150612  0.062335 -0.114164  0.206834 -0.174423 -0.143383
# 3  0.084995 -0.022497 -0.064864 -0.030642 -0.021505  0.120058 -0.033323
# 4  0.052905  0.355642 -0.147669 -0.110771  0.139467 -0.111484 -0.086481
#
#          84        85        86        87        88        89        90  \
# 0  0.039413  0.057296 -0.032883  0.178930 -0.041066 -0.291091 -0.282419
# 1 -0.338942  0.371122 -0.052994  0.244417 -0.287926 -0.218817 -0.021330
# 2 -0.194942  0.389972  0.106455  0.259786 -0.299455 -0.290938  0.021807
# 3 -0.222691  0.242486  0.092962  0.018603 -0.219664 -0.154725 -0.002171
# 4 -0.349371  0.295586 -0.089981 -0.067171 -0.360450 -0.333718 -0.238447
#
#          91        92        93        94        95        96        97  \
# 0  0.603306 -0.442489 -0.327670 -0.263256  0.461867  0.023616  0.439441
# 1  0.395019 -0.372362 -0.277778  0.037163  0.295471  0.157661  0.314650
# 2  0.434425 -0.223086 -0.174660 -0.072449  0.191839  0.075741  0.240822
# 3  0.289039 -0.125069 -0.281204  0.010688  0.262193  0.027944  0.151230
# 4  0.463355 -0.252728 -0.339298  0.028461  0.257459  0.152926  0.201800
#
#          98        99       100       101       102       103       104  \
# 0  0.235254  0.373382 -0.190634 -0.221493 -0.667009 -0.082607 -0.006312
# 1  0.176541  0.213506 -0.021481  0.029486 -0.498019 -0.047550 -0.255754
# 2  0.281865  0.108383 -0.161810 -0.187901 -0.342081  0.009544 -0.260808
# 3  0.125055  0.188927 -0.053681 -0.025389 -0.292639  0.049411 -0.285139
# 4  0.342497  0.219784 -0.138514  0.059858 -0.317369  0.072370 -0.139294
#
#         105       106       107       108       109       110       111  \
# 0 -0.390579 -0.134744  0.199869 -0.047040 -0.095199  0.438204  0.175492
# 1 -0.117963  0.088568  0.134302 -0.402002 -0.265234  0.383252  0.159932
# 2 -0.288075  0.051073  0.004536 -0.318183 -0.414206  0.147566  0.024906
# 3 -0.121680  0.051281  0.179292 -0.236445 -0.378220  0.299338 -0.154108
# 4 -0.022898 -0.017022  0.143663 -0.196159 -0.430140  0.063951 -0.006114
#
#         112       113       114       115       116       117       118  \
# 0 -0.114987 -0.110947 -0.409854 -0.133315 -0.233369  0.179327  0.113631
# 1 -0.530212 -0.060001 -0.163197 -0.357970 -0.237835  0.295675 -0.194183
# 2 -0.310370  0.054972 -0.066917 -0.145379 -0.212008  0.321734 -0.123401
# 3 -0.245200 -0.010455 -0.225823 -0.358113 -0.182551  0.267396 -0.149492
# 4 -0.278787 -0.081952 -0.072987 -0.280205 -0.174310  0.139281  0.078958
#
#         119       120       121       122       123       124       125  \
# 0  0.124691 -0.231633  0.082733 -0.298423  0.326031  0.329030  0.157246
# 1 -0.003883 -0.318181 -0.061075  0.115886  0.112178  0.226662  0.222194
# 2 -0.110092 -0.147035 -0.252981  0.200497 -0.093486  0.040278  0.114311
# 3 -0.035876 -0.161939 -0.047609  0.142945  0.033835  0.010732  0.112518
# 4 -0.020992 -0.156900 -0.032071  0.064326  0.070919  0.260380 -0.009741
#
#         126       127       128       129       130       131       132  \
# 0  0.043023 -0.406806 -0.019210  0.097610  0.154527 -0.028668  0.007515
# 1  0.292609 -0.187217  0.144786  0.055155  0.258740  0.020244 -0.014791
# 2  0.311769 -0.078079  0.197749 -0.043474  0.004409  0.040359  0.140259
# 3  0.162255 -0.213752  0.064943 -0.017400  0.081982  0.071264  0.155906
# 4  0.341686 -0.253904  0.113620  0.167235  0.139025  0.124136 -0.093230
#
#         133       134       135       136       137       138       139  \
# 0  0.157075  0.274354 -0.145701  0.505673 -0.304795 -0.314147  0.487233
# 1  0.063200  0.116612 -0.150365  0.035586 -0.136915 -0.114242 -0.113486
# 2  0.057140  0.066875 -0.129667  0.089897  0.024200  0.014155  0.004968
# 3 -0.046345  0.156536 -0.199489  0.133528  0.012668 -0.205632 -0.123320
# 4  0.060153  0.120347 -0.082689 -0.085486 -0.014939  0.048910  0.088500
#
#         140       141       142       143       144       145       146  \
# 0  0.017175 -0.057374 -0.086568 -0.270234 -0.086852  0.188279 -0.033689
# 1  0.002597  0.221838  0.006201 -0.417312  0.114375 -0.070995  0.023327
# 2  0.154011  0.245434 -0.032879 -0.231631 -0.006785 -0.062929  0.119299
# 3 -0.006324  0.304931 -0.218730 -0.070735 -0.077876  0.132799  0.049408
# 4 -0.039743  0.280168 -0.237062 -0.187121  0.053668  0.308144  0.081186
#
#         147       148       149       150       151       152       153  \
# 0 -0.337834  0.145169  0.113222 -0.062634 -0.435245 -0.306094  0.171984
# 1 -0.106340  0.107593  0.105678  0.049740 -0.264606 -0.140144 -0.431648
# 2  0.005194  0.018536 -0.070187  0.182811 -0.284503 -0.137163 -0.269879
# 3  0.060700 -0.032213 -0.001472  0.045498 -0.155506 -0.214697 -0.076349
# 4 -0.239390  0.106350  0.045241  0.160671 -0.389159 -0.318960 -0.100055
#
#         154       155       156       157       158       159       160  \
# 0 -0.089011 -0.144320  0.123949  0.113529 -0.320610 -0.164778 -0.135140
# 1 -0.477079 -0.146103 -0.017253 -0.094708 -0.006980  0.097614 -0.086166
# 2 -0.315196  0.115568  0.005625 -0.286776  0.050975  0.183587  0.027923
# 3 -0.341843  0.058911  0.068045 -0.076639  0.127489  0.175458  0.017116
# 4 -0.271291  0.019279 -0.013083  0.012124  0.110755  0.188432 -0.248873
#
#         161       162       163       164       165       166       167  \
# 0 -0.064684 -0.177959  0.108942 -0.544299  0.027349  0.356871 -0.118159
# 1  0.129233 -0.147552  0.076569 -0.254678  0.192301  0.274385  0.036670
# 2  0.033633 -0.129598  0.120354 -0.219440  0.065142  0.297414  0.051387
# 3 -0.132579 -0.207581  0.020774 -0.165189  0.009823  0.341552 -0.030435
# 4  0.013961 -0.077937  0.017908 -0.267983  0.054784  0.194690  0.147475
#
#         168       169       170       171       172       173       174  \
# 0  0.238216  0.115817  0.297036  0.648095 -0.648513 -0.161086  0.081983
# 1 -0.010373 -0.011478  0.194060  0.283602 -0.184210 -0.179025  0.102773
# 2  0.087660  0.113616  0.156505  0.268380 -0.213109 -0.162401  0.244111
# 3  0.186506  0.275057  0.176023  0.270148 -0.420341 -0.105872  0.000934
# 4  0.233133  0.101489  0.083907  0.225489 -0.407844 -0.133008  0.103064
#
#         175       176       177       178       179       180       181  \
# 0  0.004553 -0.661199 -0.273057 -0.232438  0.492083 -0.091234  0.121208
# 1 -0.073802 -0.166479 -0.130287 -0.178733 -0.090959 -0.019706  0.122582
# 2  0.173746 -0.095381  0.039599 -0.409037  0.061887  0.001013  0.394118
# 3  0.210533 -0.285709 -0.166449 -0.438567 -0.156536 -0.192139  0.416030
# 4  0.113539 -0.245718  0.075684 -0.432696 -0.023290 -0.079878  0.450487
#
#         182       183       184       185       186       187       188  \
# 0  0.234660 -0.040876  0.214551  0.206691 -0.378760  0.091240 -0.276305
# 1 -0.048456  0.074011 -0.101331 -0.030236 -0.166486  0.220083 -0.124024
# 2 -0.006244  0.158514  0.081809  0.018846 -0.086353  0.219369 -0.096790
# 3  0.020057  0.055813 -0.165853  0.126191 -0.099354  0.152571 -0.237819
# 4  0.103111  0.028772  0.104631  0.237303 -0.150501  0.032863 -0.183735
#
#         189       190       191       192       193       194       195  \
# 0  0.348394  0.189202 -0.039899  0.007252  0.023891  0.180608 -0.044694
# 1  0.005842  0.101624 -0.201897 -0.151110 -0.031324  0.047048 -0.312679
# 2 -0.021151  0.161172 -0.251882 -0.258181 -0.009543  0.119414 -0.053714
# 3 -0.087801 -0.033170 -0.143659 -0.210206 -0.007968  0.199198 -0.239404
# 4  0.123943  0.331276 -0.100025 -0.178404  0.200769  0.075553 -0.236437
#
#         196       197       198       199       200       201       202  \
# 0 -0.113823  0.068996 -0.500981  0.261934  0.043847 -0.401673 -0.230929
# 1 -0.076372  0.061432 -0.332923 -0.037514  0.292480 -0.307352  0.126516
# 2  0.043053  0.217421 -0.133478  0.008698  0.249996 -0.257376  0.069191
# 3 -0.041680  0.172614 -0.128231  0.002829  0.426928 -0.504743  0.088622
# 4 -0.059251  0.161967 -0.029123  0.083928  0.237252 -0.381130  0.059811
#
#         203       204       205       206       207       208       209  \
# 0  0.057447  0.205273 -0.200156 -0.412095  0.099247 -0.012548 -0.704206
# 1  0.038016  0.128947 -0.103601 -0.156899 -0.302557 -0.314021 -0.465241
# 2 -0.082731  0.008223 -0.268027 -0.249785 -0.275209 -0.186274 -0.265973
# 3 -0.060581  0.138801 -0.233322 -0.074589 -0.303754 -0.418314 -0.406320
# 4 -0.003736  0.093896 -0.008865 -0.099916 -0.076496 -0.162444 -0.405952
#
#         210       211       212       213       214       215       216  \
# 0 -0.237615 -0.304809  0.399941 -0.150039  0.057990 -0.394538  0.487589
# 1 -0.111973 -0.293453  0.252497 -0.001780 -0.089908 -0.155549  0.246367
# 2  0.007530  0.008643  0.043888 -0.111982 -0.025384 -0.011983  0.333552
# 3 -0.157227 -0.214343  0.198613 -0.410722 -0.057646 -0.009641  0.147896
# 4 -0.313231 -0.083848  0.270146 -0.215093 -0.277706 -0.112221  0.199396
#
#         217       218       219       220       221       222       223  \
# 0  0.292059 -0.145009 -0.312687  0.369353 -0.254717 -0.082460 -0.041843
# 1  0.341913 -0.101823 -0.235577  0.219583 -0.044168  0.082604  0.137532
# 2  0.387888 -0.101080 -0.152826  0.031806 -0.091864  0.017828  0.063288
# 3  0.308647  0.117655 -0.209586  0.095574  0.039819 -0.065898  0.207267
# 4  0.292364  0.010380 -0.046929  0.153994 -0.264840  0.174333  0.211124
#
#         224       225       226       227       228       229       230  \
# 0 -0.054188  0.541652 -0.327549 -0.123172  0.026107  0.611200  0.024999
# 1 -0.009375  0.323461 -0.325211 -0.112569  0.035180  0.322089  0.292749
# 2 -0.018386  0.348509 -0.153647 -0.053546  0.001174  0.225896  0.014327
# 3 -0.040239  0.277608 -0.202747 -0.078581  0.195786 -0.044764 -0.145326
# 4  0.101847  0.423652 -0.365786 -0.220063  0.069041  0.415262 -0.009577
#
#         231       232       233       234       235       236       237  \
# 0  0.263751 -0.162226  0.190246  0.009556 -0.056675 -0.358250  0.259278
# 1 -0.065652  0.015746  0.228130 -0.047630 -0.074180 -0.288872  0.313230
# 2  0.016892  0.010219 -0.045066 -0.030950 -0.038106 -0.261223  0.184943
# 3 -0.145257 -0.120600  0.162439 -0.028335  0.190103 -0.057958  0.038917
# 4 -0.073692 -0.015202  0.003313  0.101365  0.169221 -0.225544  0.289056
#
#         238       239       240       241       242       243       244  \
# 0 -0.118742  0.078036 -0.371248  0.163460  0.123380  0.073944  0.094856
# 1 -0.127965  0.046234 -0.180781 -0.044940  0.050943 -0.077384 -0.269473
# 2 -0.091477  0.092370 -0.154164 -0.062558  0.046808  0.019012 -0.108283
# 3  0.059067  0.066020  0.129214 -0.053936  0.013898 -0.071552 -0.206399
# 4  0.007851  0.013793 -0.382699  0.089743  0.008678  0.020631 -0.115775
#
#         245       246       247       248       249       250       251  \
# 0 -0.374406  0.075558 -0.270153 -0.604539  0.019539 -0.008587  0.439927
# 1  0.072831  0.116604 -0.168891 -0.229783  0.247559  0.037334  0.237188
# 2 -0.068228  0.056464 -0.098448 -0.285469  0.248407 -0.035714  0.107565
# 3  0.289473  0.175494  0.122831 -0.199611  0.349668 -0.086311  0.207421
# 4  0.218365 -0.062471  0.002519 -0.286133  0.389812 -0.052098  0.272734
#
#         252       253       254       255       256       257       258  \
# 0  0.039825  0.188154 -0.379745  0.210087 -0.085910  0.056213 -0.022947
# 1  0.058849 -0.157616 -0.256954  0.109634 -0.112640  0.110275  0.205120
# 2 -0.081946 -0.190026 -0.149920 -0.113285 -0.126224  0.121430 -0.019094
# 3 -0.173384 -0.145102 -0.136669  0.103072 -0.094101 -0.190838  0.053738
# 4 -0.284207 -0.078399 -0.276351  0.199086  0.048582  0.085285 -0.061025
#
#         259       260       261       262       263       264       265  \
# 0  0.209829 -0.346199  0.232295 -0.160025 -0.139382  0.597834  0.286008
# 1 -0.016592  0.086210  0.242008  0.145985 -0.115243  0.204453  0.027921
# 2 -0.020133  0.148577  0.103648  0.073967 -0.001371  0.085125  0.115746
# 3  0.161352 -0.066255 -0.018375  0.268434 -0.046975  0.015129  0.041884
# 4  0.038787  0.053211  0.252661 -0.013734 -0.180501  0.293762  0.028562
#
#         266       267       268       269       270       271       272  \
# 0  0.060557 -0.062150  0.075570 -0.494240 -0.026763  0.198833  0.116072
# 1  0.105096  0.192051  0.116738 -0.107490  0.024690 -0.069206  0.154065
# 2  0.190196  0.111641  0.008371 -0.230572 -0.027785 -0.234586 -0.014762
# 3  0.046330  0.213024  0.066065  0.089257  0.095816  0.009813 -0.021770
# 4 -0.011436  0.117337 -0.051972 -0.110146  0.047820 -0.138809  0.121214
#
#         273       274       275       276       277       278       279  \
# 0  0.043847 -0.073603 -0.102847 -0.263390  0.052392 -0.461331  0.035556
# 1  0.275091 -0.017957  0.179729 -0.172441 -0.011095 -0.171192  0.046851
# 2  0.005762 -0.030596  0.326494 -0.039787 -0.078762 -0.070605  0.121084
# 3 -0.091973  0.080057  0.030445  0.033235  0.031468 -0.012104 -0.195555
# 4  0.124878 -0.000890  0.294493  0.008790 -0.037704 -0.179488 -0.052334
#
#         280       281       282       283       284       285       286  \
# 0  0.104598 -0.242080  0.499110 -0.069143 -0.250825 -0.146353 -0.033547
# 1 -0.251241  0.012877  0.159934 -0.160145 -0.038436  0.079178  0.089671
# 2 -0.195990  0.177814  0.157342 -0.125553  0.033584  0.002932  0.130796
# 3 -0.220033  0.048767  0.277926 -0.120957 -0.016782 -0.086586  0.030298
# 4 -0.114976  0.044646  0.198367 -0.120091  0.099874  0.042875  0.095566
#
#         287       288       289       290       291       292       293  \
# 0  0.205885  0.253693 -0.447286 -0.378392  0.163971  0.358968 -0.275628
# 1  0.289350  0.191247 -0.265801 -0.169838  0.152730  0.239008 -0.206390
# 2  0.019763 -0.004392 -0.071327 -0.099395  0.064350  0.266951 -0.348339
# 3  0.111823  0.010949  0.187981 -0.035402  0.021776 -0.012220 -0.189378
# 4  0.139868 -0.035607 -0.139156 -0.287867 -0.016443  0.181116 -0.339001
#
#         294       295       296       297       298       299  cuisine
# 0 -0.135233 -0.086473 -0.145747  0.550188  0.094567 -0.226367       16
# 1 -0.017012 -0.072159 -0.322869  0.037754 -0.082875 -0.116248       12
# 2  0.049832 -0.107754 -0.292320  0.152704  0.037779 -0.076041        7
# 3 -0.012176 -0.143797 -0.213756  0.115597  0.035713  0.056161        5
# 4  0.199393 -0.273069 -0.280253  0.282349  0.203717 -0.095882        5

# %% [markdown]
# # VVIMP there are two NaN's in the dataset that we should remove and also keep this in mind while analysing the missclassification ... Why? to keep the dataset consistent during analysis

# %%
print("Indices of NaN: ", pd.isnull(data).any(1).nonzero()[0])
nan_data_indices = list(pd.isnull(data).any(1).nonzero()[0])
final_data= final_data.dropna()
print("Indices of NaN: ", pd.isnull(final_data).any(1).nonzero()[0])
output_label = final_data['cuisine']
final_label_data = final_data.cuisine
print(len(final_label_data))
final_data.drop(['cuisine'],axis=1,inplace=True)
# Out:
# Indices of NaN:  [13178 23512]
# Indices of NaN:  []
# 39772

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(final_data, output_label, shuffle=False, stratify=None, test_size=0.15, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
clf = LogisticRegression(random_state=0).fit(X_train, y_train)
train_score = clf.score(X_train,y_train)
test_score = clf.score(X_test,y_test)
print("train: ",clf.score(X_train,y_train))
print("test: ",clf.score(X_test,y_test))
# Out:
# train:  0.6495296692894752
# test:  0.6436473348977539

# %% [markdown]
# # DON'T ecxecute below code it is for GLOVE
#
# # Jump to cell 41 .. below is for Glove which dint work well
#
# ## TODO: current accuracy 55% check how to improve

# %% [markdown]
# from sklearn.svm import SVC
# from sklearn.metrics import confusion_matrix,classification_report
# from sklearn.model_selection import cross_val_score, GridSearchCV
# params_grid = [{'kernel': ['rbf'], 'gamma': [1e-3, 1e-4],
#                      'C': [1, 10, 100, 1000]},
#                     {'kernel': ['linear'], 'C': [1, 10, 100, 1000]}]
# svm_model = GridSearchCV(SVC(), params_grid, cv=5)
# svm_model.fit(X_train, y_train)

# %% [markdown]
# print('Best score for training data:', svm_model.best_score_,"\n")

# %% [markdown]
# embeddings_dict = {}
# with open("glove.6B.50d.txt", 'r') as f:
#     for line in f:
#         values = line.split()
#         word = values[0]
#         vector = np.asarray(values[1:], "float32")
#         embeddings_dict[word] = vector

# %% [markdown]
# len(embeddings_dict)
# iterator = iter(embeddings_dict.items())
# for i in range(1):
#     print(next(iterator))

# %% [markdown]
# def sent_vectorizer(sent, model):
#     sent_vec =[]
#     numw = 0
#     sent = [x for x in sent if x not in unknown_ingredients]
#     for w in sent:
#         try:
#             if numw == 0:
#                 sent_vec = model[w]
#             else:
#                 sent_vec = np.add(sent_vec, model[w])
#             numw+=1
#         except:
#             pass
#     return np.asarray(sent_vec) / numw

# %% [markdown]
# unknown_ingredients = []
# for ingredient in ingredients_new_set:
#     if ingredient not in embeddings_dict.keys():
#         unknown_ingredients.append(ingredient)

# %% [markdown]
# print(len(unknown_ingredients))

# %% [markdown]
# recipes_as_context_vectors_of_ingredients=[]
# for sentence in recipes_as_sentences_list:
#     recipes_as_context_vectors_of_ingredients.append(sent_vectorizer(sentence, embeddings_dict))

# %% [markdown]
# print("Length of vector", len(recipes_as_context_vectors_of_ingredients[0]))
# print(recipes_as_sentences_list[0])
# print("Context Vectors taindataset count records: ", len(recipes_as_context_vectors_of_ingredients))
# print("Original taindataset count records: ",len(recipes_as_sentences_list))

# %% [markdown]
# train_dataset = json.load(open('train.json','r'))
# for i,recipe in enumerate(train_dataset):
#     recipe[u'ingredients'] = recipes_as_context_vectors_of_ingredients[i]
#     recipe[u'cuisine'] = labels[recipe[u'cuisine']]

# %% [markdown]
# from pandas.io.json import json_normalize
# train_dataset_new = json_normalize(train_dataset)
# train_dataset_new.drop(['id'],axis=1,inplace=True)
# train_dataset_new.head()

# %% [markdown]
# data = pd.DataFrame(recipes_as_context_vectors_of_ingredients)
# print(data.shape)
# data.head()

# %% [markdown]
# label_data = train_dataset_new.cuisine
# print(label_data.shape)
# label_data.head()
# final_data = pd.concat([data, label_data], axis=1)
# print(final_data.shape)
# final_data.head()

# %% [markdown]
# print("Indices of NaN: ", pd.isnull(data).any(1).nonzero()[0])
# final_data= final_data.dropna()
# print("Indices of NaN: ", pd.isnull(final_data).any(1).nonzero()[0])
# output_label = final_data['cuisine']
# final_data.drop(['cuisine'],axis=1,inplace=True)

# %% [markdown]
# from sklearn.model_selection import train_test_split
# X_train, X_test, y_train, y_test = train_test_split(final_data, output_label, test_size=0.15, random_state=42)

# %% [markdown]
# from sklearn.linear_model import LogisticRegression
# clf = LogisticRegression(random_state=0).fit(X_train, y_train)
#
# print("train: ",clf.score(X_train,y_train))
# print("test: ",clf.score(X_test,y_test))

# %% [markdown]
# # Analysis

# %%
predictions = clf.predict(X_train)
predictions_test = clf.predict(X_test)

# %% [markdown]
# # These are predictions by our LR model for train+test of train.json
#
# ### Note: We are not considering test.json as there are no actual output labels present in the dataset. Since we are doing Supervised Learning.... ie. Classification Problem.

# %%
print(len(predictions))
print(len(list(y_train)))

print(len(predictions_test))
print(len(list(y_test)))
# Out:
# 33806
# 33806
# 5966
# 5966

# %%
print(predictions[:10])
print((list(y_train)[:10]))
# Out:
# [16 12 12  9  5 12  1 12  1  9]
# [16, 12, 7, 5, 5, 15, 3, 9, 1, 9]

# %% [markdown]
# # Merge Both Train and Test Prediction for complete analysis

# %%
total_predictions = list(predictions) + list(predictions_test)
len(total_predictions)
# Out:
# 39772

# %% [markdown]
# ## Note we can see that there were two NaN entries in our context vector generated dataset thus we should remove those recipes from the original dataset to maintain the dataset consistent, ie [13178, 23512]

# %%
nan_data_indices
# Out:
# [13178, 23512]

# %% [markdown]
# # below cell for confusion matrix

# %% [markdown]
# from sklearn import metrics
# cm = metrics.confusion_matrix(y_train, predictions)
# print(cm)

# %% [markdown]
# plt.figure(figsize=(9,9))
# sns.heatmap(cm, annot=True, fmt=".3f", linewidths=.5, square = True, cmap = 'Blues_r');
# plt.ylabel('Actual label');
# plt.xlabel('Predicted label');
# all_sample_title = 'Accuracy Score: {0}'.format(train_score)
# plt.title(all_sample_title, size = 15);

# %% [markdown]
# # Identifying indices of those recipes which have been missclassifed by the model

# %%
index = 0
misclassifiedIndexes = []
for label, predict in zip(list(final_label_data), total_predictions):
    if label != predict: 
        misclassifiedIndexes.append(index)
    index +=1

# %%
print(misclassifiedIndexes[:15])
print(len(misclassifiedIndexes))
# Out:
# [2, 3, 5, 6, 7, 16, 17, 19, 22, 26, 37, 38, 41, 45, 46]
# 13974

# %%
train_dataset = json.load(open('train.json','r'))
for i,recipe in enumerate(train_dataset):
    recipe[u'cuisine'] = labels[recipe[u'cuisine']]
train_dataset_new_for_analysing_missclassfication = json_normalize(train_dataset)	
train_dataset_new_for_analysing_missclassfication.drop(axis=0, index=nan_data_indices, inplace=True)               
train_dataset_new_for_analysing_missclassfication.drop(['id'],axis=1,inplace=True)
train_dataset_new_for_analysing_missclassfication.reset_index(drop=True, inplace=True)
print(train_dataset_new_for_analysing_missclassfication.shape)
train_dataset_new_for_analysing_missclassfication.head()
# Out:
# (39772, 2)
#    cuisine                                        ingredients
# 0       16  [romaine lettuce, black olives, grape tomatoes...
# 1       12  [plain flour, ground pepper, salt, tomatoes, g...
# 2        7  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3        5                [water, vegetable oil, wheat, salt]
# 4        5  [black pepper, shallots, cornflour, cayenne pe...

# %%
missclassifed_data = train_dataset_new_for_analysing_missclassfication.loc[ misclassifiedIndexes , : ]

# %%
missclassifed_data.head()
# Out:
#    cuisine                                        ingredients
# 2        7  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3        5                [water, vegetable oil, wheat, salt]
# 5       15  [plain flour, sugar, butter, eggs, fresh ginge...
# 6        3  [olive oil, salt, medium shrimp, pepper, garli...
# 7        9  [sugar, pistachio nuts, white almond bark, flo...

# %%
def get_key(val): 
    for key, value in labels.items(): 
         if val == value:
            return key
    return "key doesn't exist"

# %%
print(pd.isnull(missclassifed_data).any(1).nonzero()[0])
df1 = missclassifed_data[missclassifed_data.isna().any(axis=1)]
# Out:
# []

# %%
for i, row in missclassifed_data.iterrows():
    missclassifed_data.at[i, 'cuisine_label'] = get_key(int(row["cuisine"]))
missclassifed_data.drop(['cuisine'],axis=1,inplace=True)
missclassifed_data.rename(columns={'cuisine_label':'cuisine'}, inplace=True)

# %%
print(len(missclassifed_data))
missclassifed_data.head()
# Out:
# 13974
#                                          ingredients   cuisine
# 2  [eggs, pepper, salt, mayonaise, cooking oil, g...  filipino
# 3                [water, vegetable oil, wheat, salt]    indian
# 5  [plain flour, sugar, butter, eggs, fresh ginge...  jamaican
# 6  [olive oil, salt, medium shrimp, pepper, garli...   spanish
# 7  [sugar, pistachio nuts, white almond bark, flo...   italian

# %%
#missclassifed_data.to_json(orient='records')
missclassifed_data.cuisine.unique()
# Out:
# array(['filipino', 'indian', 'jamaican', 'spanish', 'italian', 'british',
#        'vietnamese', 'southern_us', 'cajun_creole', 'brazilian',
#        'chinese', 'french', 'japanese', 'irish', 'thai', 'korean',
#        'moroccan', 'greek', 'mexican', 'russian'], dtype=object)

# %%
misclassified_data_count = missclassifed_data.groupby('cuisine').count()
misclassified_data_count
# Out:
#               ingredients
# cuisine
# brazilian             458
# british               785
# cajun_creole          665
# chinese               468
# filipino              553
# french               1697
# greek                 696
# indian                376
# irish                 580
# italian              1052
# jamaican              372
# japanese              736
# korean                603
# mexican               666
# moroccan              470
# russian               465
# southern_us          1317
# spanish               958
# thai                  385
# vietnamese            672

# %%
train_dataset = json.load(open('train.json','r'))
print(train_dataset[0]["ingredients"])
print(recipes_as_sentences_list[0])
# Out:
# ['romaine lettuce', 'black olives', 'grape tomatoes', 'garlic', 'pepper', 'purple onion', 'seasoning', 'garbanzo beans', 'feta cheese crumbles']
# ['romaine lettuce', 'olive', 'grape tomato', 'garlic', 'pepper', 'onion', 'feta cheese']

# %%
#These are cleaned ingredients
train_dataset = json.load(open('train.json','r'))

for i,recipe in enumerate(train_dataset):
    recipe[u'ingredients'] = recipes_as_sentences_list[i]

# %%
train_dataset_pd = json_normalize(train_dataset)
train_dataset_pd.drop(axis=0, index=nan_data_indices, inplace=True)
train_dataset_pd.reset_index(drop=True, inplace=True)
train_dataset_pd.drop(['id'],axis=1,inplace=True)
train_dataset_pd_count = train_dataset_pd.groupby('cuisine').count()
train_dataset_pd_count
# Out:
#               ingredients
# cuisine
# brazilian             467
# british               804
# cajun_creole         1546
# chinese              2673
# filipino              755
# french               2645
# greek                1175
# indian               3003
# irish                 667
# italian              7838
# jamaican              526
# japanese             1423
# korean                830
# mexican              6438
# moroccan              821
# russian               489
# southern_us          4320
# spanish               989
# thai                 1538
# vietnamese            825

# %% [markdown]
# # Find the % of each cuisine wrt to the entire dataset

# %%
total_records = train_dataset_pd.shape[0]

# %%
original_cuisine_ratio = dict()
for k, v in train_dataset_pd_count["ingredients"].items():
     original_cuisine_ratio[k] = round(((v/total_records)*100), 2)

# %%
original_cuisine_ratio
# Out:
# {'brazilian': 1.17,
#  'british': 2.02,
#  'cajun_creole': 3.89,
#  'chinese': 6.72,
#  'filipino': 1.9,
#  'french': 6.65,
#  'greek': 2.95,
#  'indian': 7.55,
#  'irish': 1.68,
#  'italian': 19.71,
#  'jamaican': 1.32,
#  'japanese': 3.58,
#  'korean': 2.09,
#  'mexican': 16.19,
#  'moroccan': 2.06,
#  'russian': 1.23,
#  'southern_us': 10.86,
#  'spanish': 2.49,
#  'thai': 3.87,
#  'vietnamese': 2.07}

# %%
plt.figure(figsize=(15,5))
plt.title('Recipe Count per Cuisine in Data')
ax = train_dataset_pd.cuisine.value_counts().plot()
plt.xticks(np.arange(len(train_dataset_pd.cuisine.unique())), train_dataset_pd.cuisine.value_counts().index, rotation=80)
plt.show()

# %% [markdown]
# # Thus, in this case it makes lot of sense to only consider Italian and Mexican Cuisine for our missclassification analysis of ingredients as the dataset is unbalaned
#
# # I mean the analysis of ingredients

# %% [markdown]
# # Missclassification % per cuisine

# %%
misclassified_data_count_dict = misclassified_data_count.to_dict()
train_dataset_pd_count = train_dataset_pd_count.to_dict()

# %%
missclassification_cuisine_ratio = dict()
for (k,v), (k2,v2) in zip(misclassified_data_count_dict["ingredients"].items(), train_dataset_pd_count["ingredients"].items()):
    missclassification_cuisine_ratio[k] = round(((v/v2)*100), 2)

# %%
missclassification_cuisine_ratio
# Out:
# {'brazilian': 98.07,
#  'british': 97.64,
#  'cajun_creole': 43.01,
#  'chinese': 17.51,
#  'filipino': 73.25,
#  'french': 64.16,
#  'greek': 59.23,
#  'indian': 12.52,
#  'irish': 86.96,
#  'italian': 13.42,
#  'jamaican': 70.72,
#  'japanese': 51.72,
#  'korean': 72.65,
#  'mexican': 10.34,
#  'moroccan': 57.25,
#  'russian': 95.09,
#  'southern_us': 30.49,
#  'spanish': 96.87,
#  'thai': 25.03,
#  'vietnamese': 81.45}

# %% [markdown]
# # TODO: Analyse Italian and Mexican cuisines' ingredients and understand or research if the misclassified ingredients of Italian and Mexican cuisine have any relation with other cuisines.
